# %%
# !pip install streamlit scikit-learn nltk pandas numpy
# Out:
# Requirement already satisfied: streamlit in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (1.45.1)
# Requirement already satisfied: scikit-learn in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (1.4.1.post1)
# Requirement already satisfied: nltk in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (3.9.1)
# Requirement already satisfied: pandas in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (1.26.4)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: packaging<25,>=20 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (10.2.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (6.31.0)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (20.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from scikit-learn) (3.4.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: jinja2 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\balaj\appdata\roaming\python\python310\site-packages (from altair<6,>=4.0->streamlit) (1.40.0)
# Requirement already satisfied: colorama in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: six>=1.5 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from requests<3,>=2.27->streamlit) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\balaj\anaconda3\envs\aiml\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)

# %%
# %%writefile sentiment_webapp.py
import streamlit as st
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import string

# Download NLTK data
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')

# Preprocessing function
def preprocess_text(text):
    text = text.lower()
    text = re.sub(f'[{re.escape(string.punctuation)}]', '', text)
    text = re.sub(r'\d+', '', text)
    text = ' '.join(text.split())
    tokens = text.split()
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]
    return ' '.join(tokens)

# Sample training data (replace with your Day 4 model)
def create_sample_model():
    reviews = [
        "This movie was great! I loved it.",
        "Terrible movie, waste of time.",
        "The acting was superb.",
        "I fell asleep, so boring.",
        "One of the best movies this year!",
        "The worst movie ever made."
    ]
    sentiments = [1, 0, 1, 0, 1, 0]  # 1=Positive, 0=Negative
    
    df = pd.DataFrame({'review': reviews, 'sentiment': sentiments})
    df['processed'] = df['review'].apply(preprocess_text)
    
    vectorizer = TfidfVectorizer(max_features=1000)
    X = vectorizer.fit_transform(df['processed'])
    model = LogisticRegression()
    model.fit(X, df['sentiment'])
    
    return vectorizer, model

# Load model
vectorizer, model = create_sample_model()

# Streamlit UI
st.title("🎬 Movie Review Sentiment Analyzer")
st.write("Enter a movie review and click Predict to analyze sentiment")

user_input = st.text_area("Movie Review:", "This movie was...")

if st.button("Predict"):
    if user_input.strip() == "":
        st.warning("Please enter a review")
    else:
        # Preprocess and predict
        processed_text = preprocess_text(user_input)
        text_vector = vectorizer.transform([processed_text])
        prediction = model.predict(text_vector)
        proba = model.predict_proba(text_vector)[0]
        
        # Display results
        if prediction[0] == 1:
            st.success(f"✅ POSITIVE (Confidence: {proba[1]:.0%})")
            st.balloons()
        else:
            st.error(f"❌ NEGATIVE (Confidence: {proba[0]:.0%})")
        
        # Optional: Show explanation
        with st.expander("Analysis Details"):
            st.write("Processed Text:", processed_text)
            st.write("Prediction Probabilities:", proba)
# Out:
# Writing sentiment_webapp.py

# %%
# !streamlit run sentiment_webapp.py
